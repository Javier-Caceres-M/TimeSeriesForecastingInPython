# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.14.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %% [markdown]
# # Chapter 13

# %% [markdown]
# ## 13.1 Creating windows of data
# ### 13.1.1 Exploring how deep learning models are trained for time series forecasting

# %%
fig, ax = plt.subplots()

for n in range(0,17,2):
    start = 24*n
    stop = 24*(n+1)
    ax.plot(train_df.traffic_volume[start:stop], marker='s', color='blue', label='input')
    ax.plot(train_df.traffic_volume[stop:2*stop], marker='x', color='red', label='label')
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

# plt.savefig('figures/CH13_F01_peixeiro.png', dpi=300)

# %% [markdown]
# ### 13.1.2 Implementing the `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %% [markdown]
# ## 13.2 Applying baseline models
# ### 13.2.1 Single-step baseline model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return inputs
        
        elif isinstance(self.label_index, list):
            tensors = []
            for index in self.label_index:
                result = inputs[:, :, index]
                result = result[:, :, tf.newaxis]
                tensors.append(result)
            return tf.concat(tensors, axis=-1)
        
        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

baseline_last = Baseline(label_index=column_indices['traffic_volume'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

# %%
val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.test, verbose=0)
# Out:
# 110/110 [==============================] - 0s 882us/step - loss: 0.0133 - mean_absolute_error: 0.0831

# %%
wide_window.plot(baseline_last)

plt.savefig('figures/CH13_F09_peixeiro.png', dpi=300)

# %%
print(performance['Baseline - Last'][1])
# Out:
# 0.08128400146961212

# %% [markdown]
# ### 13.2.2 Multi-step baseline models

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %% [markdown]
# #### Predicting the last known value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 24, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %%
ms_baseline_last = MultiStepLastBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance = {}
ms_performance = {}

ms_val_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.val)
ms_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 639us/step - loss: 0.1874 - mean_absolute_error: 0.3521

# %%
multi_window.plot(ms_baseline_last)

plt.savefig('figures/CH13_F10_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Last'][1])
# Out:
# 0.3472570776939392

# %% [markdown]
# #### Repeating the input sequence

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
ms_baseline_repeat = RepeatBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.val)
ms_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 630us/step - loss: 0.2105 - mean_absolute_error: 0.3511

# %%
multi_window.plot(ms_baseline_repeat)

plt.savefig('figures/CH13_F11_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Repeat'][1])
# Out:
# 0.34394386410713196

# %% [markdown]
# ### 13.2.3 Multi-output baseline model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
print(column_indices['traffic_volume'])
print(column_indices['temp'])
# Out:
# 2
# 0

# %%
mo_baseline_last = Baseline(label_index=[0, 2])

mo_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

mo_val_performance = {}
mo_performance = {}

mo_val_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.val)
mo_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 649us/step - loss: 0.0069 - mean_absolute_error: 0.0482

# %%
mo_wide_window.plot(mo_baseline_last)

plt.savefig('figures/CH13_F12_peixeiro.png', dpi=300)

# %%
mo_wide_window.plot(model=mo_baseline_last, plot_col='temp')

plt.savefig('figures/CH13_F13_peixeiro.png', dpi=300)

# %%
print(mo_performance['Baseline - Last'][1])
# Out:
# 0.04710666462779045

# %% [markdown]
# # Chapter 14

# %% [markdown]
# ## 14.1 Implementing a linear model
# ### 14.1.1 Building a single-step linear model

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
linear = Sequential([
    Dense(units=1)
])

history = compile_and_fit(linear, single_step_window)

val_performance['Linear'] = linear.evaluate(single_step_window.val)
performance['Linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.7590 - mean_absolute_error: 0.6900 - val_loss: 0.3582 - val_mean_absolute_error: 0.4929
# Epoch 2/50
# 384/384 [==============================] - 0s 977us/step - loss: 0.2998 - mean_absolute_error: 0.4594 - val_loss: 0.2039 - val_mean_absolute_error: 0.3834
# Epoch 3/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.1678 - mean_absolute_error: 0.3431 - val_loss: 0.1142 - val_mean_absolute_error: 0.2838
# Epoch 4/50
# 384/384 [==============================] - 0s 936us/step - loss: 0.0922 - mean_absolute_error: 0.2473 - val_loss: 0.0640 - val_mean_absolute_error: 0.2079
# Epoch 5/50
# 384/384 [==============================] - 0s 938us/step - loss: 0.0516 - mean_absolute_error: 0.1779 - val_loss: 0.0384 - val_mean_absolute_error: 0.1576
# Epoch 6/50
# 384/384 [==============================] - 0s 964us/step - loss: 0.0317 - mean_absolute_error: 0.1345 - val_loss: 0.0264 - val_mean_absolute_error: 0.1283
# Epoch 7/50
# 384/384 [==============================] - 0s 915us/step - loss: 0.0226 - mean_absolute_error: 0.1115 - val_loss: 0.0208 - val_mean_absolute_error: 0.1118
# Epoch 8/50
# 384/384 [==============================] - 0s 909us/step - loss: 0.0183 - mean_absolute_error: 0.1000 - val_loss: 0.0179 - val_mean_absolute_error: 0.1036
# Epoch 9/50
# 384/384 [==============================] - 0s 975us/step - loss: 0.0158 - mean_absolute_error: 0.0932 - val_loss: 0.0157 - val_mean_absolute_error: 0.0965
# Epoch 10/50
# 384/384 [==============================] - 0s 923us/step - loss: 0.0142 - mean_absolute_error: 0.0883 - val_loss: 0.0141 - val_mean_absolute_error: 0.0914
# Epoch 11/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0129 - mean_absolute_error: 0.0843 - val_loss: 0.0127 - val_mean_absolute_error: 0.0860
# Epoch 12/50
# 384/384 [==============================] - 0s 923us/step - loss: 0.0119 - mean_absolute_error: 0.0810 - val_loss: 0.0117 - val_mean_absolute_error: 0.0821
# Epoch 13/50
# 384/384 [==============================] - 0s 909us/step - loss: 0.0112 - mean_absolute_error: 0.0782 - val_loss: 0.0110 - val_mean_absolute_error: 0.0783
# Epoch 14/50
# 384/384 [==============================] - 0s 962us/step - loss: 0.0107 - mean_absolute_error: 0.0760 - val_loss: 0.0104 - val_mean_absolute_error: 0.0760
# Epoch 15/50
# 384/384 [==============================] - 0s 920us/step - loss: 0.0103 - mean_absolute_error: 0.0740 - val_loss: 0.0100 - val_mean_absolute_error: 0.0735
# Epoch 16/50
# 384/384 [==============================] - 0s 930us/step - loss: 0.0100 - mean_absolute_error: 0.0725 - val_loss: 0.0098 - val_mean_absolute_error: 0.0708
# Epoch 17/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0097 - mean_absolute_error: 0.0712 - val_loss: 0.0095 - val_mean_absolute_error: 0.0702
# Epoch 18/50
# 384/384 [==============================] - 0s 907us/step - loss: 0.0096 - mean_absolute_error: 0.0701 - val_loss: 0.0093 - val_mean_absolute_error: 0.0695
# Epoch 19/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0095 - mean_absolute_error: 0.0694 - val_loss: 0.0092 - val_mean_absolute_error: 0.0692
# Epoch 20/50
# 384/384 [==============================] - 0s 907us/step - loss: 0.0094 - mean_absolute_error: 0.0689 - val_loss: 0.0092 - val_mean_absolute_error: 0.0684
# Epoch 21/50
# 384/384 [==============================] - 0s 943us/step - loss: 0.0093 - mean_absolute_error: 0.0685 - val_loss: 0.0091 - val_mean_absolute_error: 0.0680
# Epoch 22/50
# 384/384 [==============================] - 0s 923us/step - loss: 0.0093 - mean_absolute_error: 0.0683 - val_loss: 0.0091 - val_mean_absolute_error: 0.0686
# Epoch 23/50
# 384/384 [==============================] - 0s 904us/step - loss: 0.0093 - mean_absolute_error: 0.0680 - val_loss: 0.0091 - val_mean_absolute_error: 0.0680
# Epoch 24/50
# 384/384 [==============================] - 0s 904us/step - loss: 0.0093 - mean_absolute_error: 0.0680 - val_loss: 0.0091 - val_mean_absolute_error: 0.0683
# Epoch 25/50
# 384/384 [==============================] - 0s 912us/step - loss: 0.0093 - mean_absolute_error: 0.0679 - val_loss: 0.0091 - val_mean_absolute_error: 0.0677
# Epoch 26/50
# 384/384 [==============================] - 0s 907us/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0090 - val_mean_absolute_error: 0.0685
# Epoch 27/50
# 384/384 [==============================] - 0s 907us/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0677
# Epoch 28/50
# 384/384 [==============================] - 0s 930us/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0672
# Epoch 29/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0090 - val_mean_absolute_error: 0.0686
# Epoch 30/50
# 384/384 [==============================] - 0s 912us/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0678
# Epoch 31/50
# 384/384 [==============================] - 0s 907us/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0674
# Epoch 32/50
# 384/384 [==============================] - 0s 915us/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0671
# 110/110 [==============================] - 0s 634us/step - loss: 0.0091 - mean_absolute_error: 0.0671

# %%
wide_window.plot(linear)

plt.savefig('figures/CH14_F02_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.1.2 Building a mutli-step linear model

# %%
ms_linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(ms_linear, multi_window)

ms_val_performance['Linear'] = ms_linear.evaluate(multi_window.val)
ms_performance['Linear'] = ms_linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0929 - mean_absolute_error: 0.2530 - val_loss: 0.0464 - val_mean_absolute_error: 0.1836
# Epoch 2/50
# 383/383 [==============================] - 0s 941us/step - loss: 0.0312 - mean_absolute_error: 0.1417 - val_loss: 0.0251 - val_mean_absolute_error: 0.1228
# Epoch 3/50
# 383/383 [==============================] - 0s 920us/step - loss: 0.0201 - mean_absolute_error: 0.1050 - val_loss: 0.0206 - val_mean_absolute_error: 0.1055
# Epoch 4/50
# 383/383 [==============================] - 0s 914us/step - loss: 0.0176 - mean_absolute_error: 0.0948 - val_loss: 0.0194 - val_mean_absolute_error: 0.0996
# Epoch 5/50
# 383/383 [==============================] - 0s 907us/step - loss: 0.0168 - mean_absolute_error: 0.0906 - val_loss: 0.0188 - val_mean_absolute_error: 0.0959
# Epoch 6/50
# 383/383 [==============================] - 0s 914us/step - loss: 0.0164 - mean_absolute_error: 0.0881 - val_loss: 0.0185 - val_mean_absolute_error: 0.0935
# Epoch 7/50
# 383/383 [==============================] - 0s 949us/step - loss: 0.0162 - mean_absolute_error: 0.0865 - val_loss: 0.0183 - val_mean_absolute_error: 0.0917
# Epoch 8/50
# 383/383 [==============================] - 0s 901us/step - loss: 0.0161 - mean_absolute_error: 0.0855 - val_loss: 0.0182 - val_mean_absolute_error: 0.0909
# Epoch 9/50
# 383/383 [==============================] - 0s 914us/step - loss: 0.0161 - mean_absolute_error: 0.0849 - val_loss: 0.0182 - val_mean_absolute_error: 0.0904
# Epoch 10/50
# 383/383 [==============================] - 0s 901us/step - loss: 0.0161 - mean_absolute_error: 0.0846 - val_loss: 0.0182 - val_mean_absolute_error: 0.0901
# Epoch 11/50
# 383/383 [==============================] - 0s 904us/step - loss: 0.0161 - mean_absolute_error: 0.0844 - val_loss: 0.0182 - val_mean_absolute_error: 0.0898
# Epoch 12/50
# 383/383 [==============================] - 0s 899us/step - loss: 0.0161 - mean_absolute_error: 0.0842 - val_loss: 0.0182 - val_mean_absolute_error: 0.0897
# Epoch 13/50
# 383/383 [==============================] - 0s 914us/step - loss: 0.0161 - mean_absolute_error: 0.0842 - val_loss: 0.0182 - val_mean_absolute_error: 0.0897
# Epoch 14/50
# 383/383 [==============================] - 0s 907us/step - loss: 0.0161 - mean_absolute_error: 0.0841 - val_loss: 0.0182 - val_mean_absolute_error: 0.0897
# 109/109 [==============================] - 0s 639us/step - loss: 0.0182 - mean_absolute_error: 0.0897

# %% [markdown]
# ### 14.1.3 Implementing a multi-output linear model

# %%
mo_linear = Sequential([
    Dense(units=2)
])

history = compile_and_fit(mo_linear, mo_single_step_window)

mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.2093 - mean_absolute_error: 0.3627 - val_loss: 0.0732 - val_mean_absolute_error: 0.2196
# Epoch 2/50
# 384/384 [==============================] - 0s 915us/step - loss: 0.0421 - mean_absolute_error: 0.1634 - val_loss: 0.0336 - val_mean_absolute_error: 0.1443
# Epoch 3/50
# 384/384 [==============================] - 0s 928us/step - loss: 0.0247 - mean_absolute_error: 0.1225 - val_loss: 0.0216 - val_mean_absolute_error: 0.1158
# Epoch 4/50
# 384/384 [==============================] - 0s 949us/step - loss: 0.0167 - mean_absolute_error: 0.1001 - val_loss: 0.0151 - val_mean_absolute_error: 0.0980
# Epoch 5/50
# 384/384 [==============================] - 0s 954us/step - loss: 0.0124 - mean_absolute_error: 0.0865 - val_loss: 0.0114 - val_mean_absolute_error: 0.0860
# Epoch 6/50
# 384/384 [==============================] - 0s 915us/step - loss: 0.0100 - mean_absolute_error: 0.0773 - val_loss: 0.0093 - val_mean_absolute_error: 0.0778
# Epoch 7/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0085 - mean_absolute_error: 0.0704 - val_loss: 0.0079 - val_mean_absolute_error: 0.0706
# Epoch 8/50
# 384/384 [==============================] - 0s 915us/step - loss: 0.0074 - mean_absolute_error: 0.0645 - val_loss: 0.0068 - val_mean_absolute_error: 0.0641
# Epoch 9/50
# 384/384 [==============================] - 0s 964us/step - loss: 0.0066 - mean_absolute_error: 0.0592 - val_loss: 0.0060 - val_mean_absolute_error: 0.0583
# Epoch 10/50
# 384/384 [==============================] - 0s 909us/step - loss: 0.0060 - mean_absolute_error: 0.0544 - val_loss: 0.0055 - val_mean_absolute_error: 0.0532
# Epoch 11/50
# 384/384 [==============================] - 0s 912us/step - loss: 0.0056 - mean_absolute_error: 0.0504 - val_loss: 0.0052 - val_mean_absolute_error: 0.0493
# Epoch 12/50
# 384/384 [==============================] - 0s 917us/step - loss: 0.0053 - mean_absolute_error: 0.0472 - val_loss: 0.0050 - val_mean_absolute_error: 0.0461
# Epoch 13/50
# 384/384 [==============================] - 0s 909us/step - loss: 0.0052 - mean_absolute_error: 0.0449 - val_loss: 0.0048 - val_mean_absolute_error: 0.0440
# Epoch 14/50
# 384/384 [==============================] - 0s 959us/step - loss: 0.0051 - mean_absolute_error: 0.0432 - val_loss: 0.0048 - val_mean_absolute_error: 0.0425
# Epoch 15/50
# 384/384 [==============================] - 0s 920us/step - loss: 0.0050 - mean_absolute_error: 0.0419 - val_loss: 0.0047 - val_mean_absolute_error: 0.0412
# Epoch 16/50
# 384/384 [==============================] - 0s 962us/step - loss: 0.0050 - mean_absolute_error: 0.0410 - val_loss: 0.0047 - val_mean_absolute_error: 0.0407
# Epoch 17/50
# 384/384 [==============================] - 0s 988us/step - loss: 0.0049 - mean_absolute_error: 0.0403 - val_loss: 0.0047 - val_mean_absolute_error: 0.0396
# Epoch 18/50
# 384/384 [==============================] - 0s 920us/step - loss: 0.0049 - mean_absolute_error: 0.0399 - val_loss: 0.0047 - val_mean_absolute_error: 0.0400
# Epoch 19/50
# 384/384 [==============================] - 0s 938us/step - loss: 0.0049 - mean_absolute_error: 0.0397 - val_loss: 0.0047 - val_mean_absolute_error: 0.0394
# Epoch 20/50
# 384/384 [==============================] - 0s 920us/step - loss: 0.0049 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0395
# Epoch 21/50
# 384/384 [==============================] - 0s 967us/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0394
# Epoch 22/50
# 384/384 [==============================] - 0s 954us/step - loss: 0.0049 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0392
# Epoch 23/50
# 384/384 [==============================] - 0s 933us/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0396
# Epoch 24/50
# 384/384 [==============================] - 0s 962us/step - loss: 0.0049 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0395
# Epoch 25/50
# 384/384 [==============================] - 0s 975us/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0392
# Epoch 26/50
# 384/384 [==============================] - 0s 956us/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0394
# 110/110 [==============================] - 0s 661us/step - loss: 0.0047 - mean_absolute_error: 0.0394

# %% [markdown]
# ## 14.2 Implementing a deep neural network
# ### 14.2.1 Implementing a deep neural network as a single-step model

# %%
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)

val_performance['Dense'] = dense.evaluate(single_step_window.val)
performance['Dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0100 - mean_absolute_error: 0.0685 - val_loss: 0.0047 - val_mean_absolute_error: 0.0516
# Epoch 2/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0497 - val_loss: 0.0034 - val_mean_absolute_error: 0.0431
# Epoch 3/50
# 384/384 [==============================] - 0s 993us/step - loss: 0.0039 - mean_absolute_error: 0.0459 - val_loss: 0.0030 - val_mean_absolute_error: 0.0392
# Epoch 4/50
# 384/384 [==============================] - 0s 996us/step - loss: 0.0035 - mean_absolute_error: 0.0432 - val_loss: 0.0032 - val_mean_absolute_error: 0.0424
# Epoch 5/50
# 384/384 [==============================] - 0s 996us/step - loss: 0.0034 - mean_absolute_error: 0.0421 - val_loss: 0.0028 - val_mean_absolute_error: 0.0382
# Epoch 6/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0034 - mean_absolute_error: 0.0424 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
# Epoch 7/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0032 - mean_absolute_error: 0.0406 - val_loss: 0.0027 - val_mean_absolute_error: 0.0377
# Epoch 8/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0031 - mean_absolute_error: 0.0397 - val_loss: 0.0025 - val_mean_absolute_error: 0.0368
# Epoch 9/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0392 - val_loss: 0.0027 - val_mean_absolute_error: 0.0380
# Epoch 10/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0030 - mean_absolute_error: 0.0396 - val_loss: 0.0025 - val_mean_absolute_error: 0.0374
# Epoch 11/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0390 - val_loss: 0.0025 - val_mean_absolute_error: 0.0353
# Epoch 12/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0029 - mean_absolute_error: 0.0382 - val_loss: 0.0023 - val_mean_absolute_error: 0.0334
# Epoch 13/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0029 - mean_absolute_error: 0.0379 - val_loss: 0.0025 - val_mean_absolute_error: 0.0356
# Epoch 14/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0029 - mean_absolute_error: 0.0380 - val_loss: 0.0024 - val_mean_absolute_error: 0.0357
# Epoch 15/50
# 384/384 [==============================] - 0s 998us/step - loss: 0.0028 - mean_absolute_error: 0.0372 - val_loss: 0.0025 - val_mean_absolute_error: 0.0379
# 110/110 [==============================] - 0s 661us/step - loss: 0.0025 - mean_absolute_error: 0.0379

# %%
wide_window.plot(dense)

plt.savefig('figures/CH14_F06_peixeiro.png', dpi=300)

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.2 Implementing a deep neural network as a multi-step model

# %%
ms_dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_dense, multi_window)

ms_val_performance['Dense'] = ms_dense.evaluate(multi_window.val)
ms_performance['Dense'] = ms_dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0303 - mean_absolute_error: 0.1114 - val_loss: 0.0166 - val_mean_absolute_error: 0.0836
# Epoch 2/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0795 - val_loss: 0.0163 - val_mean_absolute_error: 0.0815
# Epoch 3/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0784 - val_loss: 0.0155 - val_mean_absolute_error: 0.0850
# Epoch 4/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0135 - mean_absolute_error: 0.0779 - val_loss: 0.0150 - val_mean_absolute_error: 0.0826
# Epoch 5/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0133 - mean_absolute_error: 0.0770 - val_loss: 0.0149 - val_mean_absolute_error: 0.0765
# Epoch 6/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0768 - val_loss: 0.0148 - val_mean_absolute_error: 0.0764
# Epoch 7/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0762 - val_loss: 0.0147 - val_mean_absolute_error: 0.0779
# Epoch 8/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0761 - val_loss: 0.0146 - val_mean_absolute_error: 0.0796
# Epoch 9/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0757 - val_loss: 0.0145 - val_mean_absolute_error: 0.0815
# Epoch 10/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0755 - val_loss: 0.0145 - val_mean_absolute_error: 0.0775
# Epoch 11/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0757 - val_loss: 0.0147 - val_mean_absolute_error: 0.0817
# Epoch 12/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0756 - val_loss: 0.0146 - val_mean_absolute_error: 0.0811
# 109/109 [==============================] - 0s 788us/step - loss: 0.0146 - mean_absolute_error: 0.0811

# %%
ms_mae_val = [v[1] for v in ms_val_performance.values()]
ms_mae_test = [v[1] for v in ms_performance.values()]

x = np.arange(len(ms_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=ms_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.3 Implementing a deep neural network as a multi-output model

# %%
mo_dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_dense, mo_single_step_window)

mo_val_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.val)
mo_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0105 - mean_absolute_error: 0.0598 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 2/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0026 - mean_absolute_error: 0.0317 - val_loss: 0.0021 - val_mean_absolute_error: 0.0284
# Epoch 3/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0292 - val_loss: 0.0017 - val_mean_absolute_error: 0.0261
# Epoch 4/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0286 - val_loss: 0.0022 - val_mean_absolute_error: 0.0296
# Epoch 5/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0279 - val_loss: 0.0017 - val_mean_absolute_error: 0.0273
# Epoch 6/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0275 - val_loss: 0.0016 - val_mean_absolute_error: 0.0248
# Epoch 7/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0272 - val_loss: 0.0015 - val_mean_absolute_error: 0.0247
# Epoch 8/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0265 - val_loss: 0.0016 - val_mean_absolute_error: 0.0258
# Epoch 9/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0264 - val_loss: 0.0016 - val_mean_absolute_error: 0.0259
# Epoch 10/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0268 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 11/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0014 - val_mean_absolute_error: 0.0245
# Epoch 12/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0015 - val_mean_absolute_error: 0.0251
# Epoch 13/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 14/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0016 - val_mean_absolute_error: 0.0258
# Epoch 15/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0013 - val_mean_absolute_error: 0.0224
# Epoch 16/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0013 - val_mean_absolute_error: 0.0231
# Epoch 17/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 18/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0243 - val_loss: 0.0012 - val_mean_absolute_error: 0.0217
# Epoch 19/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0247 - val_loss: 0.0013 - val_mean_absolute_error: 0.0225
# Epoch 20/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0244 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 21/50
# 384/384 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.0013 - val_mean_absolute_error: 0.0220
# 110/110 [==============================] - 0s 670us/step - loss: 0.0013 - mean_absolute_error: 0.0220

# %%
mo_mae_val = [v[1] for v in mo_val_performance.values()]
mo_mae_test = [v[1] for v in mo_performance.values()]

x = np.arange(len(mo_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=mo_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F09_peixeiro.png', dpi=300)
